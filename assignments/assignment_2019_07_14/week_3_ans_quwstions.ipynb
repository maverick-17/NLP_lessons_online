# %% [markdown]
# ## Part 1: review machine learning

# %% [markdown]
# 1. Why do we use Derivative / Gredient to fit a target function?¶
# ans: To find the fastest direction that loss func descend.

# %% [markdown]
# 2. In the words 'Gredient Descent', what's the Gredient and what's the Descent?¶
# ans: Gradient describe the loss func increase rate, descent means value of loss func decrease.

# %% [markdown]
# 3. What's the advantages of the 3rd gradient descent method compared to the previous methods?
# ans: Faster to find the min loss func, and each step the loss become smaller.

# %% [markdown]
# 4. Using the simple words to describe: What's the machine leanring.
# ans: Use math method to let machine make better choice.

# %% [markdown]
# ### Part 5: Answer following questions:

# %% [markdown]
# 1. Why do we need dynamic programming? What's the difference of dynamic programming and previous talked `search` problme?
# ans: Dynamic programming is a useful way find optimal decision process. Dynamic programming has a lot of subproblem.

# %% [markdown]
# 2. Why do we still need dynamic programming? Why not we train a machine learning to fit a function which could get the `right` answer based on inputs?
# ans: Dynamic programming can

# %% [markdown]
# 3. Can you catch up at least 3 problems which could solved by Dynamic Programming?
# ans:

# %% [markdown]
# 4. Please summarize the three main features of Dynamic Programming, and make a concise explain for each feature.

# %% [markdown]
# 5. What's the disadvantages of Dynamic Programming? (You may need search by yourself in Internet)
